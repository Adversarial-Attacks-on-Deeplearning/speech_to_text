# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("oortdatahub/in-car-command")

print("Path to dataset files:", path)

# %%
# !ls /root/.cache/kagglehub/datasets/oortdatahub/in-car-command/versions/2/
